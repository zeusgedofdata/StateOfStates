# %%
import pandas as pd
from dash import Dash, html, dcc, callback, Output, Input, State, dash_table
from jupyter_dash import JupyterDash
import censusgeocode as cg
import plotly.figure_factory as ff
from urllib.request import urlopen
import json
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
from sklearn.linear_model import LinearRegression
from Partisian import get_state_part_score
from Life import get_age_life_fig
from sklearn.neighbors import KNeighborsClassifier
from plotly.subplots import make_subplots
from math import floor
import GraphGenerator
from LifeData import LifeData
import math
#from GraphGenerator import cultural_ontology

# %%
number = float(75.9)
rounded = round(math.floor(number/10))*10
print('Rounded Number :', rounded)
# Out:
# Rounded Number : 70

# %%
# Out:
# Requirement already satisfied: dash in c:\users\zeusg\envs\real-fast\lib\site-packages (2.9.3)
# Collecting dash
#   Using cached dash-2.11.1-py3-none-any.whl (10.4 MB)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: nest-asyncio in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (1.5.1)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: ansi2html in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (1.8.0)
# Requirement already satisfied: retrying in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (5.3.1)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\zeusg\envs\real-fast\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\zeusg\envs\real-fast\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\zeusg\envs\real-fast\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\zeusg\envs\real-fast\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: requests in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (2.28.2)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (4.5.0)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (4.11.4)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (3.0.2)
# Requirement already satisfied: click>=8.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash) (8.0.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\zeusg\envs\real-fast\lib\site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: six in c:\users\zeusg\envs\real-fast\lib\site-packages (from plotly>=5.0.0->dash) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\zeusg\envs\real-fast\lib\site-packages (from Werkzeug<2.3.0->dash) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\zeusg\envs\real-fast\lib\site-packages (from requests->dash) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zeusg\envs\real-fast\lib\site-packages (from requests->dash) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zeusg\envs\real-fast\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zeusg\envs\real-fast\lib\site-packages (from requests->dash) (3.1.0)
# Requirement already satisfied: colorama in c:\users\zeusg\envs\real-fast\lib\site-packages (from click>=8.0->Flask<2.3.0,>=1.0.4->dash) (0.4.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\zeusg\envs\real-fast\lib\site-packages (from importlib-metadata>=3.6.0->Flask<2.3.0,>=1.0.4->dash) (3.8.0)
# Installing collected packages: dash
#   Attempting uninstall: dash
#     Found existing installation: dash 2.9.3
#     Uninstalling dash-2.9.3:
#       Successfully uninstalled dash-2.9.3
# Successfully installed dash-2.11.1

# %%
def make_dummy_graph():
    fig = go.Figure(data=go.Scatter(
    x=[1, 2, 3, 4],
    y=[10, 11, 12, 13],
    mode='markers',
    marker=dict(size=[40, 60, 80, 100],
                color=[0, 1, 2, 3])))
    return fig

# %%
app = JupyterDash(prevent_initial_callbacks="initial_duplicate")

app.config.suppress_callback_exceptions = True

app.layout = html.Div(className="row-fluid", children=[
    html.H1(children='USA', style={'textAlign':'center'}),
    html.Div(dcc.Dropdown(['State','Cultural Ontology'], 'State', id = "divide_dropdown"), className = "span8 offset2"),
    html.Div(className="container-fluid", id="graph-container", children=[]),
    #html.Div(className="container-fluid", id="graph-container-2", children=[]),
    html.Button('Submit', id='make-graph', n_clicks=0)
])

@app.callback(Output('graph-container', 'children', allow_duplicate=True),
              Input('StateWide', 'clickData'),
              State('graph-container', 'children'),
              prevent_initial_call=True)
def StateClick(stateClick, div_children):
    if stateClick:
        state = stateClick["points"][0]["location"]
        ind = stateClick["points"][0]["hovertext"]
    else:
        state="NY"
        ind="Life Exp"
    life_data = LifeData()
    df = life_data.get_state_card_data(state)
    graphs = {"LifeBarChart":GraphGenerator.create_life_bar(ind, state)}
    div_children =  display_table(div_children, df, "state-card", new_row=False)
    return display_graph(div_children, graphs)



@app.callback(Output('graph-container', 'children'),
              Input('divide_dropdown', 'value'),
              State('graph-container', 'children'))
def change_main_view(divide_category, div_children):
    if divide_category == "State":
        graphs = {"StateWide":GraphGenerator.life_us_map("Life Exp")}
    else:
        graphs = {"Ontology":GraphGenerator.cultural_ontology()}
    #graphs = [make_dummy_graph()]
    return display_graph(div_children, graphs, size=6)


def display_table(parent, df, id, new_row=True, size=4):
    span_size = f"span{size}"
    existing_ids = {}
    for i in range(len(parent)):
        try:
            existing_ids[parent[i]['props']['children'][0]['props']['children']['props']['id']] = i
        except:
            None
    print(f"Existing ids: {existing_ids}")
    new_chart =html.Div(dash_table.DataTable(
                        id=id, page_size=10, 
                        data=df.to_dict('records'),
                        style_cell={'textAlign': 'left'},
                        
                        style_as_list_view=True),
                        className=span_size, id=str(id)+"_parent")
    if len(parent)>0 and id in existing_ids.keys(): 
        parent[existing_ids[id]]['props']['children'][0] = new_chart
    else:
        if new_row:
            row = html.Div(className="row", children=[])
            row.children.append(new_chart)
            parent.append(row)
        else:
            print(f"New Chart {new_chart}")
            parent[-1]['props']['children'].append(new_chart.to_plotly_json())
        
    
    return parent

def add_dash_element(parent, element, new_row=True, id=""):
    #Check if graph already exists
    
    
    None


def display_graph(parent, graphs, new_row=True, size=6):
    span_size = f"span{size}"
    
    new_row = html.Div(className="row", children=[])
    existing_ids = {}
    for i in range(len(parent)):
        try:
            existing_ids[parent[i]['props']['children'][0]['props']['children']['props']['id']] = i
        except:
            None
    
    for id, graph in graphs.items():
        new_chart = html.Div(dcc.Graph(figure=graph, id=id), className=span_size, id=str(id)+"_parent")
        if id in graphs.keys() and len(parent)>0 and id in existing_ids.keys(): 
            parent[existing_ids[id]]['props']['children'][0] = new_chart
        else:
            new_row.children.append(new_chart)
            parent.append(new_row)

    return parent

    


if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash app running on http://127.0.0.1:8050/
# NY
#     index State  Year         Indicator   Rate  Rank
# 0      31    NY  2020          Life Exp  77.70    35
# 3      31    NY  2020  Infant Mortality   4.08     6
# 11     31    NY  2021    Fertility Rate  54.10    12
# 20     31    NY  2021  Low Birth Weight   8.40    26
# 29     31    NY  2021         Premature   9.69    14
# 38     31    NY  2021        Teen Birth   9.10     9
# 47     31    NY  2021   Unmarried Birth  38.10    23
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 77.7, 'Rank': 35}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 4.08, 'Rank': 6}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 54.1, 'Rank': 12}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 8.4, 'Rank': 26}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.69, 'Rank': 14}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 9.1, 'Rank': 9}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 38.1, 'Rank': 23}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# NE
#     index State  Year         Indicator   Rate  Rank
# 0      26    NE  2020          Life Exp  77.70    35
# 3      26    NE  2020  Infant Mortality   5.68    28
# 11     26    NE  2021    Fertility Rate  64.40    47
# 20     26    NE  2021  Low Birth Weight   7.64    17
# 29     26    NE  2021         Premature  10.79    32
# 38     26    NE  2021        Teen Birth  14.00    28
# 47     26    NE  2021   Unmarried Birth  34.20    12
# Existing ids: {'StateWide': 0, 'LifeBarChart': 1}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 77.7, 'Rank': 35}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 5.68, 'Rank': 28}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 64.4, 'Rank': 47}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 7.64, 'Rank': 17}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 10.79, 'Rank': 32}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 14.0, 'Rank': 28}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 34.2, 'Rank': 12}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# MN
#     index State  Year         Indicator   Rate  Rank
# 0      22    MN  2020          Life Exp  79.10    48
# 3      22    MN  2020  Infant Mortality   4.13     7
# 11     22    MN  2021    Fertility Rate  58.60    32
# 20     22    MN  2021  Low Birth Weight   7.25    10
# 29     22    MN  2021         Premature   9.62    12
# 38     22    MN  2021        Teen Birth   8.50     8
# 47     22    MN  2021   Unmarried Birth  31.80     7
# Existing ids: {'StateWide': 0, 'LifeBarChart': 1}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 79.1, 'Rank': 48}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 4.13, 'Rank': 7}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 58.6, 'Rank': 32}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 7.25, 'Rank': 10}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.62, 'Rank': 12}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 8.5, 'Rank': 8}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 31.8, 'Rank': 7}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# TX
#     index State  Year         Indicator   Rate  Rank
# 0      42    TX  2020          Life Exp  76.50    21
# 3      42    TX  2020  Infant Mortality   5.29    22
# 11     42    TX  2021    Fertility Rate  60.70    38
# 20     42    TX  2021  Low Birth Weight   8.65    28
# 29     42    TX  2021         Premature  11.38    41
# 38     42    TX  2021        Teen Birth  20.30    42
# 47     42    TX  2021   Unmarried Birth  41.30    32
# Existing ids: {'StateWide': 0, 'LifeBarChart': 1}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 76.5, 'Rank': 21}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 5.29, 'Rank': 22}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 60.7, 'Rank': 38}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 8.65, 'Rank': 28}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 11.38, 'Rank': 41}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 20.3, 'Rank': 42}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 41.3, 'Rank': 32}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# NM
#     index State  Year         Indicator   Rate  Rank
# 0      30    NM  2020          Life Exp  74.50     9
# 3      30    NM  2020  Infant Mortality   5.30    23
# 11     30    NM  2021    Fertility Rate  52.90    10
# 20     30    NM  2021  Low Birth Weight   9.40    39
# 29     30    NM  2021         Premature  10.02    23
# 38     30    NM  2021        Teen Birth  19.00    41
# 47     30    NM  2021   Unmarried Birth  52.40    48
# Existing ids: {'StateWide': 0, 'LifeBarChart': 1}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 74.5, 'Rank': 9}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 5.3, 'Rank': 23}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 52.9, 'Rank': 10}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 9.4, 'Rank': 39}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 10.02, 'Rank': 23}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 19.0, 'Rank': 41}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 52.4, 'Rank': 48}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# MO
#     index State  Year         Indicator   Rate  Rank
# 0      24    MO  2020          Life Exp  75.10    12
# 3      24    MO  2020  Infant Mortality   5.89    32
# 11     24    MO  2021    Fertility Rate  58.40    31
# 20     24    MO  2021  Low Birth Weight   8.89    32
# 29     24    MO  2021         Premature  11.28    39
# 38     24    MO  2021        Teen Birth  17.10    38
# 47     24    MO  2021   Unmarried Birth  39.90    28
# Existing ids: {'StateWide': 0, 'LifeBarChart': 1}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 75.1, 'Rank': 12}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 5.89, 'Rank': 32}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 58.4, 'Rank': 31}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 8.89, 'Rank': 32}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 11.28, 'Rank': 39}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 17.1, 'Rank': 38}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 39.9, 'Rank': 28}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# MS
#     index State  Year         Indicator   Rate  Rank
# 0      23    MS  2020          Life Exp  71.90     1
# 3      23    MS  2020  Infant Mortality   8.12    50
# 11     23    MS  2021    Fertility Rate  60.70    38
# 20     23    MS  2021  Low Birth Weight  12.35    50
# 29     23    MS  2021         Premature  14.96    50
# 38     23    MS  2021        Teen Birth  25.60    49
# 47     23    MS  2021   Unmarried Birth  54.80    50
# Existing ids: {'StateWide': 0, 'LifeBarChart': 1}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 71.9, 'Rank': 1}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 8.12, 'Rank': 50}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 60.7, 'Rank': 38}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 12.35, 'Rank': 50}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 14.96, 'Rank': 50}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 25.6, 'Rank': 49}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 54.8, 'Rank': 50}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# NY
#     index State  Year         Indicator   Rate  Rank
# 0      31    NY  2020          Life Exp  77.70    35
# 3      31    NY  2020  Infant Mortality   4.08     6
# 11     31    NY  2021    Fertility Rate  54.10    12
# 20     31    NY  2021  Low Birth Weight   8.40    26
# 29     31    NY  2021         Premature   9.69    14
# 38     31    NY  2021        Teen Birth   9.10     9
# 47     31    NY  2021   Unmarried Birth  38.10    23
# NY
#     index State  Year         Indicator   Rate  Rank
# 0      31    NY  2020          Life Exp  77.70    35
# 3      31    NY  2020  Infant Mortality   4.08     6
# 11     31    NY  2021    Fertility Rate  54.10    12
# 20     31    NY  2021  Low Birth Weight   8.40    26
# 29     31    NY  2021         Premature   9.69    14
# 38     31    NY  2021        Teen Birth   9.10     9
# 47     31    NY  2021   Unmarried Birth  38.10    23
# NY
#     index State  Year         Indicator   Rate  Rank
# 0      31    NY  2020          Life Exp  77.70    35
# 3      31    NY  2020  Infant Mortality   4.08     6
# 11     31    NY  2021    Fertility Rate  54.10    12
# 20     31    NY  2021  Low Birth Weight   8.40    26
# 29     31    NY  2021         Premature   9.69    14
# 38     31    NY  2021        Teen Birth   9.10     9
# 47     31    NY  2021   Unmarried Birth  38.10    23
# NY
#     index State  Year         Indicator   Rate  Rank
# 0      31    NY  2020          Life Exp  77.70    35
# 3      31    NY  2020  Infant Mortality   4.08     6
# 11     31    NY  2021    Fertility Rate  54.10    12
# 20     31    NY  2021  Low Birth Weight   8.40    26
# 29     31    NY  2021         Premature   9.69    14
# 38     31    NY  2021        Teen Birth   9.10     9
# 47     31    NY  2021   Unmarried Birth  38.10    23
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 77.7, 'Rank': 35}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 4.08, 'Rank': 6}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 54.1, 'Rank': 12}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 8.4, 'Rank': 26}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.69, 'Rank': 14}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 9.1, 'Rank': 9}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 38.1, 'Rank': 23}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 77.7, 'Rank': 35}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 4.08, 'Rank': 6}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 54.1, 'Rank': 12}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 8.4, 'Rank': 26}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.69, 'Rank': 14}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 9.1, 'Rank': 9}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 38.1, 'Rank': 23}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 77.7, 'Rank': 35}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 4.08, 'Rank': 6}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 54.1, 'Rank': 12}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 8.4, 'Rank': 26}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.69, 'Rank': 14}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 9.1, 'Rank': 9}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 38.1, 'Rank': 23}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 77.7, 'Rank': 35}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 4.08, 'Rank': 6}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 54.1, 'Rank': 12}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 8.4, 'Rank': 26}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.69, 'Rank': 14}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 9.1, 'Rank': 9}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 38.1, 'Rank': 23}], page_size=10, style_as_list_view=True, style_cell={'textAlign': 'left'}, id='state-card'), id='state-card_parent', className='span4')

# %%
a = {1:"test"}

# %%
if 1 in a.keys():
    print("weoo")
# Out:
# weoo
# NY
#     index State  Year         Indicator   Rate  Rank
# 0      31    NY  2020          Life Exp  77.70    35
# 3      31    NY  2020  Infant Mortality   4.08     6
# 11     31    NY  2021    Fertility Rate  54.10    12
# 20     31    NY  2021  Low Birth Weight   8.40    26
# 29     31    NY  2021         Premature   9.69    14
# 38     31    NY  2021        Teen Birth   9.10     9
# 47     31    NY  2021   Unmarried Birth  38.10    23
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 77.7, 'Rank': 35}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 4.08, 'Rank': 6}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 54.1, 'Rank': 12}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 8.4, 'Rank': 26}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.69, 'Rank': 14}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 9.1, 'Rank': 9}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 38.1, 'Rank': 23}], page_size=10, id='state-card'), id='state-card_parent', className='span_4')
# state-card
# KS
#     index State  Year         Indicator   Rate  Rank
# 0      15    KS  2020          Life Exp  76.40    20
# 3      15    KS  2020  Infant Mortality   6.60    39
# 11     15    KS  2021    Fertility Rate  61.00    42
# 20     15    KS  2021  Low Birth Weight   7.40    13
# 29     15    KS  2021         Premature   9.83    18
# 38     15    KS  2021        Teen Birth  16.30    34
# 47     15    KS  2021   Unmarried Birth  35.90    15
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 76.4, 'Rank': 20}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 6.6, 'Rank': 39}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 61.0, 'Rank': 42}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 7.4, 'Rank': 13}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.83, 'Rank': 18}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 16.3, 'Rank': 34}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 35.9, 'Rank': 15}], page_size=10, id='state-card'), id='state-card_parent', className='span_4')
# state-card
# CO
#     index State  Year         Indicator   Rate  Rank
# 0       5    CO  2020          Life Exp  78.30    39
# 3       5    CO  2020  Infant Mortality   4.80    14
# 11      5    CO  2021    Fertility Rate  52.50     8
# 20      5    CO  2021  Low Birth Weight   9.48    42
# 29      5    CO  2021         Premature   9.75    16
# 38      5    CO  2021        Teen Birth  11.40    17
# 47      5    CO  2021   Unmarried Birth  22.80     2
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 78.3, 'Rank': 39}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 4.8, 'Rank': 14}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 52.5, 'Rank': 8}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 9.48, 'Rank': 42}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.75, 'Rank': 16}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 11.4, 'Rank': 17}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 22.8, 'Rank': 2}], page_size=10, id='state-card'), id='state-card_parent', className='span_4')
# state-card
# UT
#     index State  Year         Indicator   Rate  Rank
# 0      43    UT  2020          Life Exp  78.60    42
# 3      43    UT  2020  Infant Mortality   5.43    24
# 11     43    UT  2021    Fertility Rate  63.60    46
# 20     43    UT  2021  Low Birth Weight   7.42    14
# 29     43    UT  2021         Premature   9.89    19
# 38     43    UT  2021        Teen Birth   9.70    11
# 47     43    UT  2021   Unmarried Birth  19.50     1
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 78.6, 'Rank': 42}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 5.43, 'Rank': 24}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 63.6, 'Rank': 46}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 7.42, 'Rank': 14}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.89, 'Rank': 19}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 9.7, 'Rank': 11}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 19.5, 'Rank': 1}], page_size=10, id='state-card'), id='state-card_parent', className='span_4')
# state-card
# UT
#     index State  Year         Indicator   Rate  Rank
# 0      43    UT  2020          Life Exp  78.60    42
# 3      43    UT  2020  Infant Mortality   5.43    24
# 11     43    UT  2021    Fertility Rate  63.60    46
# 20     43    UT  2021  Low Birth Weight   7.42    14
# 29     43    UT  2021         Premature   9.89    19
# 38     43    UT  2021        Teen Birth   9.70    11
# 47     43    UT  2021   Unmarried Birth  19.50     1
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 78.6, 'Rank': 42}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 5.43, 'Rank': 24}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 63.6, 'Rank': 46}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 7.42, 'Rank': 14}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 9.89, 'Rank': 19}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 9.7, 'Rank': 11}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 19.5, 'Rank': 1}], page_size=10, id='state-card'), id='state-card_parent', className='span_4')
# state-card
# WY
#     index State  Year         Indicator   Rate  Rank
# 0      49    WY  2020          Life Exp  76.30    18
# 3      49    WY  2020  Infant Mortality   5.22    21
# 11     49    WY  2021    Fertility Rate  57.50    26
# 20     49    WY  2021  Low Birth Weight   9.40    39
# 29     49    WY  2021         Premature  10.84    34
# 38     49    WY  2021        Teen Birth  16.00    32
# 47     49    WY  2021   Unmarried Birth  32.90     9
# Existing ids: {'StateWide': 0}
# New Chart Div(children=DataTable(data=[{'Year': 2020, 'Indicator': 'Life Exp', 'Rate': 76.3, 'Rank': 18}, {'Year': 2020, 'Indicator': 'Infant Mortality', 'Rate': 5.22, 'Rank': 21}, {'Year': 2021, 'Indicator': 'Fertility Rate', 'Rate': 57.5, 'Rank': 26}, {'Year': 2021, 'Indicator': 'Low Birth Weight', 'Rate': 9.4, 'Rank': 39}, {'Year': 2021, 'Indicator': 'Premature', 'Rate': 10.84, 'Rank': 34}, {'Year': 2021, 'Indicator': 'Teen Birth', 'Rate': 16.0, 'Rank': 32}, {'Year': 2021, 'Indicator': 'Unmarried Birth', 'Rate': 32.9, 'Rank': 9}], page_size=10, id='state-card'), id='state-card_parent', className='span_4')
# state-card

# %%
app = JupyterDash(prevent_initial_callbacks="initial_duplicate")

app.config.suppress_callback_exceptions = True

app.layout = html.Div(className="row-fluid", children=[
    html.H1(children='USA', style={'textAlign':'center'}),
    html.Div(dcc.Dropdown(['State','Cultural Ontology'], 'State', id = "divide_dropdown"), className = "span8 offset2"),
    html.Div(className="container-fluid", id="graph-container", children=[]),
    #html.Div(className="container-fluid", id="graph-container-2", children=[]),
    html.Button('Submit', id='make-graph', n_clicks=0)
])

@app.callback(Output('graph-container', 'children', allow_duplicate=True),
              Input('StateWide', 'clickData'),
              State('graph-container', 'children'),
              prevent_initial_call=True)
def StateClick(stateClick, div_children):
    if stateClick:
        state = stateClick["points"][0]["location"]
        ind = stateClick["points"][0]["hovertext"]
    else:
        state="NY"
        ind="Life Exp"
    life_data = LifeData()
    df = life_data.get_state_card_data(state)
    graphs = {"LifeBarChart":GraphGenerator.create_life_bar(ind, state), "StateCard":life_data.get_state_card_data(state)}
    
    #div_children =  table_factory(div_children, df, "state-card", new_row=True)
    return graph_factory(div_children, graphs)



@app.callback(Output('graph-container', 'children'),
              Input('divide_dropdown', 'value'),
              State('graph-container', 'children'))
def change_main_view(divide_category, div_children):
    if divide_category == "State":
        graphs = {"StateWide":GraphGenerator.life_us_map("Life Exp")}
    else:
        graphs = {"Ontology":GraphGenerator.cultural_ontology()}
    #graphs = [make_dummy_graph()]
    return graph_factory(div_children, graphs)


def table_factory(parent, df, id, new_row=True):
    existing_ids = {}
    for i in range(len(parent)):
        try:
            existing_ids[parent[i]['props']['children'][0]['props']['children']['props']['id']] = i
        except:
            None
    print(f"Existing ids: {existing_ids}")
    new_chart =html.Div(dash_table.DataTable(id=id, page_size=10, data=df.to_dict('records')), id=str(id)+"_parent")
    if len(parent)>0 and id in existing_ids.keys(): 
        parent[existing_ids[id]]['props']['children'][0] = new_chart
    else:
        new_row = html.Div(className="row", children=[])
        new_row.children.append(new_chart)
        parent.append(new_row)
    return parent


def graph_factory(parent, graphs, new_row=True, size=12):
    span_size = f"span_{size}"
    new_row = html.Div(className="row", children=[])
    existing_ids = {}
    for i in range(len(parent)):
        try:
            existing_ids[parent[i]['props']['children'][0]['props']['children']['props']['id']] = i
        except:
            None
    
    for id, graph in graphs.items():
        new_chart = html.Div(dcc.Graph(figure=graph, id=id), className=span_size, id=str(id)+"_parent")
        if id in graphs.keys() and len(parent)>0 and id in existing_ids.keys(): 
            parent[existing_ids[id]]['props']['children'][0] = new_chart
        else:
            
            new_row.children.append(new_chart)
            parent.append(new_row)

    return parent

    


if __name__ == '__main__':
    app.run_server(debug=True)
